# %%
# Write a program to find the largest of three numbers using if-else.

number_1 = int(input("Enter first number: "))
number_2 = int(input("Enter second number: "))
number_3 = int(input("Enter third number: "))

large = None
if (number_1 > number_2):
	if (number_1 > number_3):
		large = number_1
	else:
		large = number_3
else:
	if number_2 > number_3:
		large = number_2
	else:
		large = number_3
		
print(f'Largest of {number_1}, {number_2}, {number_3} is {large}')
# Out:
# Enter first number:  245
# Enter second number:  3553
# Enter third number:  4223
# Largest of 245, 3553, 4223 is 4223
