# %%
# !pip install python-docx
# Out:
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.1.1)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0

# %%
import docx

def read_docx(file_path):
  try:
    document = docx.Document(file_path)

    print(f"--- Reading: {file_path} ---")

    paragraphs = enumerate(document.paragraphs)

    for i, paragraph in paragraphs:
      if paragraph.text.strip():
        print(f"Paragraph {i+1}: {paragraph.text}")
      else:
        print(f'Paragraph {i + 1} is empty')
  except FileNotFoundError:
    print(f"Error: The file at '{file_path}' was not found.")
  except Exception as e:
    print(f"An error occurred: {e}")

read_docx('sample_data/NLP.docx')
# Out:
# --- Reading: sample_data/NLP.docx ---
# [(0, <docx.text.paragraph.Paragraph object at 0x79be9e368a10>), (1, <docx.text.paragraph.Paragraph object at 0x79be9e36a960>), (2, <docx.text.paragraph.Paragraph object at 0x79be9e3687d0>), (3, <docx.text.paragraph.Paragraph object at 0x79be9e36ac00>), (4, <docx.text.paragraph.Paragraph object at 0x79be9e368ad0>), (5, <docx.text.paragraph.Paragraph object at 0x79be9e368620>), (6, <docx.text.paragraph.Paragraph object at 0x79be9e36b170>), (7, <docx.text.paragraph.Paragraph object at 0x79be9e36a1b0>), (8, <docx.text.paragraph.Paragraph object at 0x79be9e36b7d0>), (9, <docx.text.paragraph.Paragraph object at 0x79be9e36a6c0>)]
# Paragraph 1 is empty
# Paragraph 2 is empty
# Paragraph 3: Natural Language Processing (NLP) is a multidisciplinary field of artificial intelligence (AI), computer science, and linguistics concerned with the interactions between computers and human languages. The ultimate objective of NLP is to program computers to process, analyze, and understand large amounts of natural language data, enabling them to read, decipher, and derive meaning from human tongues in a way that is valuable. While human language is inherently organic, nuanced, and unstructured, computers require structured, precise data to operate. Bridging this gap is the central challenge—and triumph—of NLP technology.
# Paragraph 4 is empty
# Paragraph 5: Natural Language Processing (NLP) is a multidisciplinary field of artificial intelligence (AI), computer science, and linguistics concerned with the interactions between computers and human languages. The ultimate objective of NLP is to program computers to process, analyze, and understand large amounts of natural language data, enabling them to read, decipher, and derive meaning from human tongues in a way that is valuable. While human language is inherently organic, nuanced, and unstructured, computers require structured, precise data to operate. Bridging this gap is the central challenge—and triumph—of NLP technology.
# Paragraph 6 is empty
# Paragraph 7: Natural Language Processing (NLP) is a multidisciplinary field of artificial intelligence (AI), computer science, and linguistics concerned with the interactions between computers and human languages. The ultimate objective of NLP is to program computers to process, analyze, and understand large amounts of natural language data, enabling them to read, decipher, and derive meaning from human tongues in a way that is valuable. While human language is inherently organic, nuanced, and unstructured, computers require structured, precise data to operate. Bridging this gap is the central challenge—and triumph—of NLP technology.
# Paragraph 8 is empty
# Paragraph 9: Natural Language Processing (NLP) is a multidisciplinary field of artificial intelligence (AI), computer science, and linguistics concerned with the interactions between computers and human languages. The ultimate objective of NLP is to program computers to process, analyze, and understand large amounts of natural language data, enabling them to read, decipher, and derive meaning from human tongues in a way that is valuable. While human language is inherently organic, nuanced, and unstructured, computers require structured, precise data to operate. Bridging this gap is the central challenge—and triumph—of NLP technology.
# Paragraph 10 is empty
