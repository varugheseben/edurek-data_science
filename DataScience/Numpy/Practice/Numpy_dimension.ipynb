# %%
# Getting number of dimension of numpy array
#      Note:
#	     Dimensions are determined based on number of opening square brackets. If no square bracket then dimension will be 0. If one square bracket then dimension will 1.
#		 If 2 square bracket then dimension will 2, if 3 square bracket then dimension will be 3 and so on


import numpy as np
array_1 = np.array([1, 2, 3, 4])
print(f'Number of dimension of {array_1} is {array_1.ndim}') # will print 1

array_2 = np.array('A')
print(f'Number of dimension of {array_2} is {array_2.ndim}') # will print 0

array_3 = np.array([[1,2,3],[4,5,6]])
print(f'Number of dimension of {array_3} is {array_3.ndim}') # will print 2

array_4 = np.array([[[1,2,3]], [[4,5,6]]])
print(f'Number of dimension of {array_4} is {array_4.ndim}') # will print 3

array_5 = np.array([])
print(f'Number of dimension of {array_5} is {array_5.ndim}') # will print 1
# Out:
# Number of dimension of [1 2 3 4] is 1
# Number of dimension of A is 0
# Number of dimension of [[1 2 3]
#  [4 5 6]] is 2
# Number of dimension of [[[1 2 3]]
#
#  [[4 5 6]]] is 3
# Number of dimension of [] is 1
