# %%
# Create two arrays and perform element-wise addition.

import numpy as np

array1 = np.array([3, 5, 6, 8, 10])

array2 = np.array([1, 2, 7, 9, 15])

summed_array = array1 + array2 

print(summed_array)
# Out:
# [ 4  7 13 17 25]
