# %%
# Example for reading CSV file
import pandas as pd

# By default, Pandas will read first 5 rows & columns and last 5 rows & columns
df = pd.read_csv("data/world_literacy.csv")
print(df)
# Out:
#            Entity      Code  Year  Illiterate  Literate
# 0     Afghanistan       AFG  1950   97.000000   3.00000
# 1     Afghanistan       AFG  1979   82.000000  18.00000
# 2     Afghanistan       AFG  2011   69.000000  31.00000
# 3     Afghanistan       AFG  2015   66.246155  33.75384
# 4     Afghanistan       AFG  2021   63.000000  37.00000
# ...           ...       ...   ...         ...       ...
# 2054     Zanzibar  OWID_ZAN  1950   92.500000   7.50000
# 2055     Zimbabwe       ZWE  1950   77.500000  22.50000
# 2056     Zimbabwe       ZWE  1982   22.000000  78.00000
# 2057     Zimbabwe       ZWE  1992   16.000000  84.00000
# 2058     Zimbabwe       ZWE  2019    6.772453  93.22755
#
# [2059 rows x 5 columns]

# %%
# Printing the entire data of a csv file
import pandas as pd

df = pd.read_csv("data/world_literacy.csv")
print(df.to_string())
# Out:
#                                                    Entity      Code  Year  Illiterate    Literate
# 0                                             Afghanistan       AFG  1950   97.000000    3.000000
# 1                                             Afghanistan       AFG  1979   82.000000   18.000000
# 2                                             Afghanistan       AFG  2011   69.000000   31.000000
# 3                                             Afghanistan       AFG  2015   66.246155   33.753840
# 4                                             Afghanistan       AFG  2021   63.000000   37.000000
# 5                                                 Albania       ALB  1950   27.500000   72.500000
# 6                                                 Albania       ALB  2001    1.000000   99.000000
# 7                                                 Albania       ALB  2008    4.000000   96.000000
# 8                                                 Albania       ALB  2011    3.000000   97.000000
# ...
