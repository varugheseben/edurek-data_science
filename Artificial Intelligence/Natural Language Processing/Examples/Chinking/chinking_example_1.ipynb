# %%
# !pip install svgling

import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# Collecting svgling
#   Downloading svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading svgling-0.5.0-py3-none-any.whl (31 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.5.0 svgwrite-1.4.3
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk import word_tokenize, pos_tag
from nltk.chunk import RegexpParser
from IPython.display import display
import svgling

texts = [
    'The clever programmer is coding in Python.',
    'The car will quickly start.',
    'They should have committed the code.',
    'The data analyst found a critical trend in the massive dataset.'
]

# Define a master grammar combining NP, VP, and PP
grammar = """
    NP:
    {<.*>+} # Chunking rule
    }<IN|DT>{ # Chink rule to remove <IN> or <DT>

"""

chunk_parser = RegexpParser(grammar)

for text in texts:
  tokens = word_tokenize(text)
  pos_tags = pos_tag(tokens)

  tree = chunk_parser.parse(pos_tags)

  # Display the resulting tree
  print(f'{text}')
  print(tree)
  tree_graphic = svgling.draw_tree(tree)
  display(tree_graphic)
  print('*' * 75,"\n\n")
# Out:
# The clever programmer is coding in Python.
# (S
#   The/DT
#   (NP clever/NN programmer/NN is/VBZ coding/VBG)
#   in/IN
#   (NP Python/NNP ./.))
# TreeLayout(Tree('S', [('The', 'DT'), Tree('NP', [('clever', 'NN'), ('programmer', 'NN'), ('is', 'VBZ'), ('coding', 'VBG')]), ('in', 'IN'), Tree('NP', [('Python', 'NNP'), ('.', '.')])]))
# ***************************************************************************
#
#
# The car will quickly start.
# (S The/DT (NP car/NN will/MD quickly/RB start/VB ./.))
# TreeLayout(Tree('S', [('The', 'DT'), Tree('NP', [('car', 'NN'), ('will', 'MD'), ('quickly', 'RB'), ('start', 'VB'), ('.', '.')])]))
# ***************************************************************************
#
#
# They should have committed the code.
# (S
#   (NP They/PRP should/MD have/VB committed/VBN)
#   the/DT
#   (NP code/NN ./.))
# TreeLayout(Tree('S', [Tree('NP', [('They', 'PRP'), ('should', 'MD'), ('have', 'VB'), ('committed', 'VBN')]), ('the', 'DT'), Tree('NP', [('code', 'NN'), ('.', '.')])]))
# ***************************************************************************
#
#
# The data analyst found a critical trend in the massive dataset.
# (S
#   The/DT
#   (NP data/NNS analyst/NN found/VBD)
#   a/DT
#   (NP critical/JJ trend/NN)
#   in/IN
#   the/DT
#   (NP massive/JJ dataset/NN ./.))
# TreeLayout(Tree('S', [('The', 'DT'), Tree('NP', [('data', 'NNS'), ('analyst', 'NN'), ('found', 'VBD')]), ('a', 'DT'), Tree('NP', [('critical', 'JJ'), ('trend', 'NN')]), ('in', 'IN'), ('the', 'DT'), Tree('NP', [('massive', 'JJ'), ('dataset', 'NN'), ('.', '.')])]))
# ***************************************************************************
