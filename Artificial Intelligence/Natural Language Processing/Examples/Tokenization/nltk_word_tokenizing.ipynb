# %%
import nltk
from nltk.tokenize import word_tokenize

prompt = input("Enter your query: ")
tokens = word_tokenize(prompt)

print(tokens)
# Out:
# Enter your query: Learning Natural Language Processing
# ['Learning', 'Natural', 'Language', 'Processing']

# %%
# Note dot character will be used as a separate token and will be removed as a stopword
import nltk
from nltk.tokenize import word_tokenize

prompt = input("Enter your query: ")
tokens = word_tokenize(prompt)

print(tokens)
# Out:
# Enter your query: Learning Natural Language Processing.
# ['Learning', 'Natural', 'Language', 'Processing', '.']
