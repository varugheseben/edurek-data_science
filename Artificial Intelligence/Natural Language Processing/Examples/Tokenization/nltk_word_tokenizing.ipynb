# %%
import nltk
from nltk.tokenize import word_tokenize

prompt = input("Enter your query")
tokens = word_tokenize(prompt)

print(tokens)
# Out:
# Enter your queryLearning Natural Language Processing
# ['Learning', 'Natural', 'Language', 'Processing']
