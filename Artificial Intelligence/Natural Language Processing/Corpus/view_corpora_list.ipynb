# %%
import os

for corpora in os.listdir('/root/nltk_data/corpora/'):
  print(corpora)
# Out:
# biocreative_ppi.zip
# opinion_lexicon
# genesis
# machado.zip
# pros_cons.zip
# webtext
# kimmo
# nonbreaking_prefixes
# senseval.zip
# indian.zip
# cess_cat.zip
# mte_teip5.zip
# english_wordnet.zip
# product_reviews_1.zip
# knbc.zip
# paradigms.zip
# movie_reviews.zip
# smultron
# europarl_raw
# conll2002
# state_union.zip
# floresta.zip
# gazetteers.zip
# lin_thesaurus.zip
# panlex_swadesh.zip
# problem_reports
# abc.zip
# sentence_polarity
# crubadan.zip
# nps_chat.zip
# gutenberg.zip
# abc
# lin_thesaurus
# conll2000.zip
# mock_corpus
# english_wordnet
# unicode_samples
# wordnet31.zip
# dolch.zip
# brown_tei
# nps_chat
# verbnet
# biocreative_ppi
# wordnet2022
# rte.zip
# toolbox.zip
# subjectivity
# state_union
# movie_reviews
# comparative_sentences
# framenet_v15
# mte_teip5
# dependency_treebank.zip
# chat80
# europarl_raw.zip
# product_reviews_2
# brown
# semcor.zip
# ieer
# dependency_treebank
# udhr
# mock_corpus.zip
# wordnet2021.zip
# ppattach
# cmudict
# ...
