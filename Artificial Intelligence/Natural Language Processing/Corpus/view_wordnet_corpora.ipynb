# %%
import nltk
from nltk.corpus import wordnet

syn_sets = wordnet.synsets('car')

for index in range(len(syn_sets)):
  print(f'{index + 1}: Meaning of car -> {syn_sets[index].definition()}')
# Out:
# 1: Meaning of car -> a motor vehicle with four wheels; usually propelled by an internal combustion engine
# 2: Meaning of car -> a wheeled vehicle adapted to the rails of railroad
# 3: Meaning of car -> the compartment that is suspended from an airship and that carries personnel and the cargo and the power plant
# 4: Meaning of car -> where passengers ride up and down
# 5: Meaning of car -> a conveyance for passengers or freight on a cable railway
