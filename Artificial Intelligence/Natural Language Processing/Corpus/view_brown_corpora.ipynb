# %%
import nltk
from nltk.corpus import brown

categories = brown.categories()
for c in categories:
  print(c)
# Out:
# adventure
# belles_lettres
# editorial
# fiction
# government
# hobbies
# humor
# learned
# lore
# mystery
# news
# religion
# reviews
# romance
# science_fiction
